# %%
# %pip install langgraph
# Out:
# Collecting langgraph
#   Using cached langgraph-0.4.8-py3-none-any.whl.metadata (6.8 kB)
# Collecting langchain-core>=0.1 (from langgraph)
#   Using cached langchain_core-0.3.65-py3-none-any.whl.metadata (5.8 kB)
# Collecting langgraph-checkpoint>=2.0.26 (from langgraph)
#   Using cached langgraph_checkpoint-2.1.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt>=0.2.0 (from langgraph)
#   Using cached langgraph_prebuilt-0.2.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk>=0.1.42 (from langgraph)
#   Using cached langgraph_sdk-0.1.70-py3-none-any.whl.metadata (1.5 kB)
# Collecting pydantic>=2.7.4 (from langgraph)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Using cached xxhash-3.5.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting langsmith<0.4,>=0.3.45 (from langchain-core>=0.1->langgraph)
#   Using cached langsmith-0.3.45-py3-none-any.whl.metadata (15 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core>=0.1->langgraph)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core>=0.1->langgraph)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting PyYAML>=5.3 (from langchain-core>=0.1->langgraph)
#   Using cached PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting packaging<25,>=23.2 (from langchain-core>=0.1->langgraph)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from langchain-core>=0.1->langgraph) (4.14.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached orjson-3.10.18-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Collecting requests<3,>=2 (from langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached zstandard-0.23.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting anyio (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.7.4->langgraph)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2.7.4->langgraph)
#   Using cached pydantic_core-2.33.2-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2.7.4->langgraph)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2->langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint>=2.0.26->langgraph)
#   Using cached ormsgpack-1.10.0-cp311-cp311-win_amd64.whl.metadata (44 kB)
# Collecting sniffio>=1.1 (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core>=0.1->langgraph)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached langgraph-0.4.8-py3-none-any.whl (152 kB)
# Using cached langchain_core-0.3.65-py3-none-any.whl (438 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langsmith-0.3.45-py3-none-any.whl (363 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached orjson-3.10.18-cp311-cp311-win_amd64.whl (134 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl (495 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.6.15-py3-none-any.whl (157 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading langgraph_checkpoint-2.1.0-py3-none-any.whl (43 kB)
# Downloading langgraph_prebuilt-0.2.2-py3-none-any.whl (23 kB)
# Downloading langgraph_sdk-0.1.70-py3-none-any.whl (49 kB)
# Downloading ormsgpack-1.10.0-cp311-cp311-win_amd64.whl (121 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading xxhash-3.5.0-cp311-cp311-win_amd64.whl (30 kB)
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, urllib3, typing-inspection, tenacity, sniffio, PyYAML, pydantic-core, packaging, ormsgpack, orjson, jsonpointer, idna, h11, charset_normalizer, certifi, annotated-types, requests, pydantic, jsonpatch, httpcore, anyio, requests-toolbelt, httpx, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph
#
#    -- -------------------------------------  2/30 [urllib3]
#    -- -------------------------------------  2/30 [urllib3]
#    -- -------------------------------------  2/30 [urllib3]
#    -- -------------------------------------  2/30 [urllib3]
#    -- -------------------------------------  2/30 [urllib3]
#    ---- -----------------------------------  3/30 [typing-inspection]
#    ----- ----------------------------------  4/30 [tenacity]
#    ------ ---------------------------------  5/30 [sniffio]
#    -------- -------------------------------  6/30 [PyYAML]
#    -------- -------------------------------  6/30 [PyYAML]
#    -------- -------------------------------  6/30 [PyYAML]
#    --------- ------------------------------  7/30 [pydantic-core]
#   Attempting uninstall: packaging
#    --------- ------------------------------  7/30 [pydantic-core]
#     Found existing installation: packaging 25.0
#    --------- ------------------------------  7/30 [pydantic-core]
#     Uninstalling packaging-25.0:
#    --------- ------------------------------  7/30 [pydantic-core]
#       Successfully uninstalled packaging-25.0
#    --------- ------------------------------  7/30 [pydantic-core]
#    ---------- -----------------------------  8/30 [packaging]
#    ---------- -----------------------------  8/30 [packaging]
#    -------------- ------------------------- 11/30 [jsonpointer]
#    ---------------- ----------------------- 12/30 [idna]
#    ----------------- ---------------------- 13/30 [h11]
#    ------------------ --------------------- 14/30 [charset_normalizer]
#    ------------------ --------------------- 14/30 [charset_normalizer]
#    --------------------- ------------------ 16/30 [annotated-types]
#    ---------------------- ----------------- 17/30 [requests]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    ------------------------ --------------- 18/30 [pydantic]
#    -------------------------- ------------- 20/30 [httpcore]
#    -------------------------- ------------- 20/30 [httpcore]
#    -------------------------- ------------- 20/30 [httpcore]
#    -------------------------- ------------- 20/30 [httpcore]
#    ---------------------------- ----------- 21/30 [anyio]
#    ---------------------------- ----------- 21/30 [anyio]
#    ---------------------------- ----------- 21/30 [anyio]
#    ---------------------------- ----------- 21/30 [anyio]
#    ----------------------------- ---------- 22/30 [requests-toolbelt]
#    ----------------------------- ---------- 22/30 [requests-toolbelt]
#    ----------------------------- ---------- 22/30 [requests-toolbelt]
#    ------------------------------ --------- 23/30 [httpx]
#    ------------------------------ --------- 23/30 [httpx]
#    ------------------------------ --------- 23/30 [httpx]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    -------------------------------- ------- 24/30 [langsmith]
#    --------------------------------- ------ 25/30 [langgraph-sdk]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langchain-core]
#    ------------------------------------ --- 27/30 [langgraph-checkpoint]
#    ------------------------------------ --- 27/30 [langgraph-checkpoint]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    -------------------------------------- - 29/30 [langgraph]
#    ---------------------------------------- 30/30 [langgraph]
#
# Successfully installed PyYAML-6.0.2 annotated-types-0.7.0 anyio-4.9.0 certifi-2025.6.15 charset_normalizer-3.4.2 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.65 langgraph-0.4.8 langgraph-checkpoint-2.1.0 langgraph-prebuilt-0.2.2 langgraph-sdk-0.1.70 langsmith-0.3.45 orjson-3.10.18 ormsgpack-1.10.0 packaging-24.2 pydantic-2.11.7 pydantic-core-2.33.2 requests-2.32.4 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 typing-inspection-0.4.1 urllib3-2.4.0 xxhash-3.5.0 zstandard-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import Dict , TypedDict
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
    message:str

def greeting_node(state:AgentState)->AgentState:

    state['message']= "Hey" + state["message"]+ ", How's the day"

    return state

# %%
graph = StateGraph(AgentState)

graph.add_node("greeter",greeting_node)
graph.set_entry_point("greeter")
graph.set_finish_point("greeter")

app=graph.compile()

# %%
# %pip install ipython
# Out:
# Requirement already satisfied: ipython in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (9.3.0)
# Requirement already satisfied: colorama in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from ipython) (4.14.0)
# Requirement already satisfied: wcwidth in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from stack_data->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\hp\desktop\ai_agents\.venv\lib\site-packages (from stack_data->ipython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from Ipython.display import Image , display
display(Image(app.get_graph().draw_mermaid_png()))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from Ipython.display import Image , display
#       2 display(Image(app.get_graph().draw_mermaid_png()))
#
# ModuleNotFoundError: No module named 'Ipython'

# %%
res = app.invoke({"message":"Mandy"})

# %%
res["message"]
# Out:
# "HeyMandy, How's the day"
